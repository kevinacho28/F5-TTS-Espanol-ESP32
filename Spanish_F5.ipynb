# %%
pip install git+https://github.com/jpgallegoar/Spanish-F5.git
# Out:
# ...
#   Cloning https://github.com/jpgallegoar/Spanish-F5.git to c:\users\pc\appdata\local\temp\pip-req-build-o7pd90xr
#   Resolved https://github.com/jpgallegoar/Spanish-F5.git to commit 33f08c9b8348ca3aa1b509554f1043fa480f3f20
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# ...
#   Using cached soundfile-0.12.1-py2.py3-none-win_amd64.whl (1.0 MB)
# ...
#   Using cached gradio-3.45.2-py3-none-any.whl (20.2 MB)
# ...
#   Using cached ema_pytorch-0.7.3-py3-none-any.whl (9.6 kB)
# ...
#   Using cached bitsandbytes-0.44.1-py3-none-win_amd64.whl (121.5 MB)
# ...
#   Using cached torchaudio-2.7.0-cp310-cp310-win_amd64.whl (2.5 MB)
# ...
#   Using cached transformers-stream-generator-0.0.5.tar.gz (13 kB)
# ...

# %%
# !f5-tts_infer-gradio
# Out:
# ^C
